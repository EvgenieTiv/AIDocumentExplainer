# %%
from pathlib import Path

from load_data import (
    extract_text_from_pdf,
    preview_pdf_pages,
    clean_text_for_llm,
    truncate_text,
)
from process_model import summarize_document_to_json, print_summary


# =====================
# Configuration
# =====================
pdf_path = Path("Data/water.pdf")
document_mode = "research"   # later: news_article, policy, general, etc.
preview_pages = True
preview_chars_per_page = 1200
max_chars_for_llm = 12000


# =====================
# Step 1. Load PDF
# =====================
full_text, page_count = extract_text_from_pdf(pdf_path)

# print(f"PDF loaded: {pdf_path.name}")
# print(f"Page count: {page_count}")
# print(f"Raw text length: {len(full_text)}")


# =====================
# Step 2. Optional page preview
# =====================
if preview_pages:
    preview_pdf_pages(pdf_path, chars_per_page=preview_chars_per_page)


# =====================
# Step 3. Clean text
# =====================
cleaned_text = clean_text_for_llm(full_text)

# print(f"Cleaned text length: {len(cleaned_text)}")
# print("\nCleaned text preview:\n")
# print(cleaned_text[:1500])


# =====================
# Step 4. Truncate for LLM
# =====================
truncated_text = truncate_text(cleaned_text, max_chars=max_chars_for_llm)

# print(f"\nFinal text length for LLM: {len(truncated_text)}")
# print("\nFinal text preview:\n")
# print(truncated_text[:1500])


# =====================
# Step 5. Run model
# =====================
result = summarize_document_to_json(document_mode, truncated_text)


# =====================
# Step 6. Print result
# =====================
# print("\n" + "=" * 80)
# print("DOCUMENT EXPLANATION RESULT")
# print("=" * 80 + "\n")

print_summary(result)
# Out:
# 📘 Title: Water Usage in Households: An Exploratory Data Analysis
# 📄 Document type: research report
# 🏷 Main topic: Household water consumption and its socioeconomic and demographic determinants
#
# 🎯 Research goal:
#
# To explore the relationship between household water consumption and factors such as income level, number of residents and guests, and apartment type using statistical analysis.
#
# 🧾 Summary:
#
# This report analyzes a dataset of 14,000 household water consumption records to test three hypotheses regarding water usage patterns. The study confirms that minimum water consumption per person remains stable regardless of water price or income level, disproves the idea that guests have a consistently lower impact on total water consumption than residents, and confirms a strong association between income level and apartment type after feature engineering. The analysis highlights data quality issues such as missing values, mixed apartment type categories, and imbalanced guest data. Despite these limitations, the study demonstrates that careful data preprocessing can reveal meaningful socioeconomic patterns in water usage.
#
# 🔍 Key findings:
# - Minimum per-person water consumption remains stable across income levels and water prices, confirming inelastic demand for basic water use.
# - Guests do not consistently have a lower impact on total household water consumption compared to residents; this hypothesis was disproved.
# - Income level is strongly associated with apartment type, with each income group owning apartment types consistent with their expected luxury level after separating flats and houses.
# - The original 'Apartment Type' feature was misleading and required feature engineering to separate flats and private houses for accurate analysis.
# - Data limitations include missing and invalid values, unclear geographic origin, and imbalanced guest data, which affect the reliability of some conclusions.
#
# ⚠️ Limitations:
# - The dataset contains missing and corrupted data, including negative values and invalid categories.
# - The 'Apartment Type' feature mixed flats and houses, complicating analysis until feature engineering was applied.
# - Geographic origin of the data is unknown and assumed to be India without validation.
# - Data on households with multiple guests is very limited, reducing reliability of guest impact analysis.
# - Amenities data is partly unreliable and requires validation.
#
# 🧠 Simplified explanation:
#
# This study looked at how much water people use in their homes and whether things like income, number of people living there, and type of home affect water use. It found that everyone uses a basic amount of water no matter the price or income, guests don’t always use less water than residents, and richer people tend to live in nicer homes. The data had some problems, but by fixing and organizing it carefully, the study was able to find useful patterns.
#
# ❓ Suggested questions:
# - How would the results change if more balanced data on households with multiple guests were collected?
# - Can the findings about income and apartment type be generalized to other regions or countries?
# - What additional features or data could improve predictive models of household water consumption?
