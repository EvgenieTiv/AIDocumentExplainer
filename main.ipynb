# %%
from pathlib import Path

from load_data import (
    extract_text_from_pdf,
    preview_pdf_pages,
    clean_text_for_llm,
    truncate_text,
    remove_image_captions
)
from process_model import summarize_document_to_json, print_summary

# =====================
# Configuration
# =====================
pdf_path = Path("Data/install_washing_machine.pdf")
# document_mode = "research"   # later: news_article, policy, general, etc.
# document_mode = "news_article"
document_mode = "instruction"
preview_pages = True
preview_chars_per_page = 1200
max_chars_for_llm = 12000


# =====================
# Step 1. Load PDF
# =====================
full_text, page_count = extract_text_from_pdf(pdf_path)

# print(f"PDF loaded: {pdf_path.name}")
# print(f"Page count: {page_count}")
# print(f"Raw text length: {len(full_text)}")


# =====================
# Step 2. Optional page preview
# =====================
if preview_pages:
    preview_pdf_pages(pdf_path, chars_per_page=preview_chars_per_page)


# =====================
# Step 3. Clean text
# =====================
cleaned_text = clean_text_for_llm(full_text)
cleaned_text = remove_image_captions(cleaned_text)

# print(f"Cleaned text length: {len(cleaned_text)}")
# print("\nCleaned text preview:\n")
# print(cleaned_text[:1500])


# =====================
# Step 4. Truncate for LLM
# =====================
truncated_text = truncate_text(cleaned_text, max_chars=max_chars_for_llm)

# print(f"\nFinal text length for LLM: {len(truncated_text)}")
# print("\nFinal text preview:\n")
# print(truncated_text[:1500])


# =====================
# Step 5. Run model
# =====================
result = summarize_document_to_json(document_mode, truncated_text)


# =====================
# Step 6. Print result
# =====================
# print("\n" + "=" * 80)
# print("DOCUMENT EXPLANATION RESULT")
# print("=" * 80 + "\n")

print_summary(result)
# Out:
# 🛠 Title: How to Install a Washing Machine
# 📄 Document type: instruction
#
# 🎯 Goal:
#
# Install a washing machine and connect it to water supply and drainage.
#
# 🧾 Summary:
#
# Remove old washer, prepare new unit, connect water supply and drain hoses, level the machine, and test operation.
#
# 📦 Prerequisites:
# - Existing plumbing with hot and cold water supply valves
# - Drain pipe or sink for wastewater
# - Electrical outlet near installation site
# - Tools: adjustable wrench or pliers, level
#
# 🪜 Main steps:
# 1. Turn off and unplug old washing machine.
# 2. Turn off hot and cold water supply valves.
# 3. Disconnect water supply hoses and drain hose from old machine.
# 4. Remove old washing machine from location.
# 5. Measure space and doorways to ensure new washer fits.
# 6. Remove carriage bolts and packaging from new washing machine.
# 7. Attach water supply hoses to hot and cold water valves and to washing machine connections.
# 8. Insert drain hose into standpipe or sink using a hose guide to prevent kinks.
# 9. Turn on water supply valves and check for leaks; tighten connections if needed without overtightening.
# 10. Level the washing machine by adjusting legs and securing locknuts.
# 11. Plug in the washing machine and run a test load to ensure proper operation and no leaks.
#
# ⚠️ Warnings or common mistakes:
# - Do not overtighten water supply hose connections to avoid damaging rubber washers and causing leaks.
# - Do not stretch water supply hoses; use longer hoses if needed.
# - Ensure washing machine is perfectly level to prevent it from moving or banging during operation.
# - Do not attempt plumbing installation without professional help if no existing plumbing is available.
#
# ✅ Expected result:
#
# A fully installed, leveled, and operational washing machine connected to water supply and drainage without leaks.
#
# 🧠 Simplified explanation:
#
# Remove the old washer, connect the new one to water and drain pipes, make sure it is level, plug it in, and test it.
#
# 📊 Confidence: high
